# %% [markdown]
# ### Required Imports for Web Scraping And Converting To DataFrame

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import bs4
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ### Load the content using reuqests module convert it to html readable

# %%
page = requests.get("https://www.imdb.com/search/title/?sort=num_votes,desc&start=1&title_type=feature&year=1950,2012")
contents = page.content

# %% [markdown]
# ### Create a Static Html file of the same to use later and store it

# %%
print(type(contents))
with open('IMDB_Movies_HTML_Page.html','ab') as fb:
    fb.write(contents)
# Out:
# <class 'bytes'>

# %% [markdown]
# ### Parse content using BeautifulSoup4's html.parse

# %%
soup = BeautifulSoup(contents,"html.parser")

# %% [markdown]
# ### Clean the data by removing unneccessary html tags and create dictionary to store data

# %%
### Data_Clean_Soup=soup.find_all("div","lister-item mode-advanced")
Dict_Of_IMDB_Data = { 'Movie_Name' : [0,],'Duration_Minute':[0,],'Genre':[0,],'Rating':[0,],"Text":[0,],'Directores':[0,],'Stars_Heroes':[0,],'User_Votes':[0,],'Gross_In_Million':[0,]}
Dict_Of_IMDB_Data

# %% [markdown]
# ### Use find_all or find to get required data from the parser

# %%
#Data_Clean_Soup[0].find_all('a')[1].string                                  Movie Name
#Data_Clean_Soup[0].find_all('a')[13].string                                 Director
#Data_Clean_Soup[0].find_all('a')[14:]                                       all the heroes who worked in movie
#Data_Clean_Soup[0].find("span","runtime").string[:-4]                       duration
#Data_Clean_Soup[0].find("span","genre").string.strip('\n ')                 genre
#Data_Clean_Soup[0].find("span","value").string                              Rating
#Data_Clean_Soup[0].find_all('p')[1].string.strip('\n ')                     Text
#Data_Clean_Soup[0].find_all('span')[-4].string                              Vote
#Data_Clean_Soup[0].find_all('span')[-1].string[:-1]                         gross
#{ 'Movie_Name' : [],'Duration_Minute':[],'genre':[],'rating':[],"Text":[],'Directores':[],'Stars_Heroes':[],'User_Votes':[],'Gross_In_Million':[]}

# %% [markdown]
# ### Convert Data to the List to Save in Dictionary

# %%
Movie=[]
Genre=[]
Rating=[]
Text=[]
Directores=[]
User_Vote=[]
Gross=[]
Duration=[]
Stars=[]
get=[]
try:
    for i in range(len(Data_Clean_Soup)):
        get=i
        Movie.append(Data_Clean_Soup[i].find_all('a')[1].string)
        Genre.append(Data_Clean_Soup[i].find("span","genre").string.strip())
        Duration.append(Data_Clean_Soup[i].find("span","runtime").string[:-4])
        Rating.append(Data_Clean_Soup[i].find("span","value").string)
        Text.append(Data_Clean_Soup[i].find_all('p')[1].find(text=True).strip())
        Directores.append(Data_Clean_Soup[i].find_all('a')[13].string)
        User_Vote.append(Data_Clean_Soup[i].find_all('span')[-4].string)
        Gross.append(Data_Clean_Soup[i].find_all('span')[-1].string[:-1])
        list_actor =[]
        total_list = Data_Clean_Soup[i].find_all('a')[14:]
        for i in total_list:
            list_actor.append(i.string)
        Stars.append(','.join(list_actor))
except:
    print("Get Error on Line with Data index : ",get)

# %% [markdown]
# ### Add data to the Dictionary

# %%
Dict_Of_IMDB_Data['Movie_Name']=Movie
Dict_Of_IMDB_Data['Genre'] = Genre
Dict_Of_IMDB_Data['Duration_Minute'] =Duration
Dict_Of_IMDB_Data['Rating'] = Rating
Dict_Of_IMDB_Data['Text'] = Text
Dict_Of_IMDB_Data['Directores'] = Directores
Dict_Of_IMDB_Data['User_Votes'] = User_Vote
Dict_Of_IMDB_Data['Gross_In_Million'] = Gross
Dict_Of_IMDB_Data['Stars_Heroes']= Stars

# %% [markdown]
# ### Create DataFrame Using Pandas

# %%
IMDB_Movie_Data = pd.DataFrame(Dict_Of_IMDB_Data)
IMDB_Movie_Data
# Out:
#                                            Movie_Name Duration_Minute  \
# 0                            The Shawshank Redemption             142
# 1                                     The Dark Knight             152
# 2                                           Inception             148
# 3                                          Fight Club             139
# 4                                        Pulp Fiction             154
# 5                                        Forrest Gump             142
# 6                                          The Matrix             136
# 7   The Lord of the Rings: The Fellowship of the Ring             178
# 8       The Lord of the Rings: The Return of the King             201
# 9                                       The Godfather             175
# 10                              The Dark Knight Rises             164
# 11              The Lord of the Rings: The Two Towers             179
# 12                                              Se7en             127
# 13                                   Django Unchained             165
# 14                                          Gladiator             155
# 15                                      Batman Begins             140
# 16                                       The Avengers             143
# 17                           The Silence of the Lambs             118
# 18                               Inglourious Basterds             153
# 19                                          Star Wars             121
# 20                                Saving Private Ryan             169
# 21                                   Schindler's List             195
# 22                                       The Departed             151
# 23                                       The Prestige             130
# 24     Star Wars: Episode V - The Empire Strikes Back             124
# 25                                     The Green Mile             189
# 26                                             Avatar             162
# 27                                            Memento             113
# 28                             The Godfather: Part II             202
# 29                                     Shutter Island             138
# 30                                    American Beauty             122
# 31                                            Titanic             194
# 32                                 Back to the Future             116
# 33                                 American History X             119
# 34                                     V for Vendetta             132
# 35  Pirates of the Caribbean: The Curse of the Bla...             143
# 36                                               Léon             110
# 37                                         Goodfellas             146
# 38                                  Kill Bill: Vol. 1             111
# 39                         Terminator 2: Judgment Day             137
# 40                                             WALL·E              98
# 41                                 The Usual Suspects             106
# 42                                         Braveheart             178
# 43         Star Wars: Episode VI - Return of the Jedi             131
# 44                                       Finding Nemo             100
# 45                                           Iron Man             126
# 46                                      The Lion King              88
# 47                                                 Up              96
# 48                                    The Truman Show             103
# 49                                     Reservoir Dogs              99
#
#                            Genre Rating  \
# 0                          Drama    9.3
# 1           Action, Crime, Drama      9
# 2      Action, Adventure, Sci-Fi    8.8
# 3                          Drama    8.8
# 4                   Crime, Drama    8.9
# 5                 Drama, Romance    8.8
# 6                 Action, Sci-Fi    8.7
# 7       Action, Adventure, Drama    8.8
# 8      Adventure, Drama, Fantasy    8.9
# 9                   Crime, Drama    9.2
# 10             Action, Adventure    8.4
# 11     Adventure, Drama, Fantasy    8.7
# 12         Crime, Drama, Mystery    8.6
# 13                Drama, Western    8.4
# 14      Action, Adventure, Drama    8.5
# 15             Action, Adventure    8.2
# 16     Action, Adventure, Sci-Fi      8
# 17        Crime, Drama, Thriller    8.6
# 18         Adventure, Drama, War    8.3
# 19    Action, Adventure, Fantasy    8.6
# 20                    Drama, War    8.6
# 21     Biography, Drama, History    8.9
# 22        Crime, Drama, Thriller    8.5
# 23        Drama, Mystery, Sci-Fi    8.5
# 24    Action, Adventure, Fantasy    8.7
# 25         Crime, Drama, Fantasy    8.6
# 26    Action, Adventure, Fantasy    7.8
# 27             Mystery, Thriller    8.4
# 28                  Crime, Drama      9
# 29             Mystery, Thriller    8.1
# 30                         Drama    8.3
# 31                Drama, Romance    7.8
# 32     Adventure, Comedy, Sci-Fi    8.5
# 33                         Drama    8.5
# 34         Action, Drama, Sci-Fi    8.2
# 35    Action, Adventure, Fantasy      8
# 36          Action, Crime, Drama    8.5
# 37       Biography, Crime, Drama    8.7
# 38       Action, Crime, Thriller    8.1
# 39                Action, Sci-Fi    8.5
# 40  Animation, Adventure, Family    8.4
# 41      Crime, Mystery, Thriller    8.5
# 42     Biography, Drama, History    8.3
# 43    Action, Adventure, Fantasy    8.3
# 44  Animation, Adventure, Comedy    8.1
# 45     Action, Adventure, Sci-Fi    7.9
# 46   Animation, Adventure, Drama    8.5
# 47  Animation, Adventure, Comedy    8.2
# 48         Comedy, Drama, Sci-Fi    8.1
# 49        Crime, Drama, Thriller    8.3
#
#                                                  Text            Directores  \
# 0   Two imprisoned men bond over a number of years...        Frank Darabont
# 1   When the menace known as the Joker wreaks havo...     Christopher Nolan
# 2   A thief who steals corporate secrets through t...     Christopher Nolan
# 3   An insomniac office worker and a devil-may-car...         David Fincher
# 4   The lives of two mob hitmen, a boxer, a gangst...     Quentin Tarantino
# 5   The presidencies of Kennedy and Johnson, the e...       Robert Zemeckis
# 6   A computer hacker learns from mysterious rebel...        Lana Wachowski
# 7   A meek Hobbit from the Shire and eight compani...         Peter Jackson
# 8   Gandalf and Aragorn lead the World of Men agai...         Peter Jackson
# 9   The aging patriarch of an organized crime dyna...  Francis Ford Coppola
# 10  Eight years after the Joker's reign of anarchy...     Christopher Nolan
# 11  While Frodo and Sam edge closer to Mordor with...         Peter Jackson
# 12  Two detectives, a rookie and a veteran, hunt a...         David Fincher
# 13  With the help of a German bounty hunter, a fre...     Quentin Tarantino
# 14  A former Roman General sets out to exact venge...          Ridley Scott
# 15  After training with his mentor, Batman begins ...     Christopher Nolan
# 16  Earth's mightiest heroes must come together an...           Joss Whedon
# 17  A young F.B.I. cadet must receive the help of ...        Jonathan Demme
# 18  In Nazi-occupied France during World War II, a...     Quentin Tarantino
# 19  Luke Skywalker joins forces with a Jedi Knight...          George Lucas
# 20  Following the Normandy Landings, a group of U....      Steven Spielberg
# 21  In German-occupied Poland during World War II,...       Oskar Schindler
# 22  An undercover cop and a mole in the police att...       Martin Scorsese
# 23  After a tragic accident, two stage magicians e...     Christopher Nolan
# 24  After the Rebels are brutally overpowered by t...        Irvin Kershner
# 25  The lives of guards on Death Row are affected ...        Frank Darabont
# 26  A paraplegic Marine dispatched to the moon Pan...         James Cameron
# 27  A man with short-term memory loss attempts to ...     Christopher Nolan
# 28  The early life and career of Vito Corleone in ...  Francis Ford Coppola
#
# 26  Sam Worthington,Zoe Saldana,Sigourney Weaver,M...  1,092,654
# 27  Guy Pearce,Carrie-Anne Moss,Joe Pantoliano,Mar...  1,084,904
# 28  Al Pacino,Robert De Niro,Robert Duvall,Diane K...  1,082,627
# 29  Leonardo DiCaprio,Emily Mortimer,Mark Ruffalo,...  1,079,456
# 30  Kevin Spacey,Annette Bening,Thora Birch,Wes Be...  1,038,720
# 31  Leonardo DiCaprio,Kate Winslet,Billy Zane,Kath...  1,011,743
# 32  Michael J. Fox,Christopher Lloyd,Lea Thompson,...  1,005,323
# 33  Edward Norton,Edward Furlong,Beverly D'Angelo,...  1,003,012
# 34  Hugo Weaving,Natalie Portman,Rupert Graves,Ste...    997,400
# 35  Johnny Depp,Geoffrey Rush,Orlando Bloom,Keira ...    994,419
# 36  Jean Reno,Gary Oldman,Natalie Portman,Danny Ai...    993,702
# 37  Martin Scorsese,Robert De Niro,Ray Liotta,Joe ...    976,570
# 38  Uma Thurman,David Carradine,Daryl Hannah,Micha...    965,343
# 39  Arnold Schwarzenegger,Linda Hamilton,Edward Fu...    964,096
# 40   Ben Burtt,Elissa Knight,Jeff Garlin,Fred Willard    963,143
# 41  Kevin Spacey,Gabriel Byrne,Chazz Palminteri,St...    957,047
# 42  Mel Gibson,Sophie Marceau,Patrick McGoohan,Ang...    933,060
# 43  Mark Hamill,Harrison Ford,Carrie Fisher,Billy ...    918,129
# 44  Lee Unkrich,Albert Brooks,Ellen DeGeneres,Alex...    918,050
# 45  Robert Downey Jr.,Gwyneth Paltrow,Terrence How...    912,090
# 46  Rob Minkoff,Matthew Broderick,Jeremy Irons,Jam...    905,116
# 47  Bob Peterson,Edward Asner,Jordan Nagai,John Ra...    900,381
# 48    Jim Carrey,Ed Harris,Laura Linney,Noah Emmerich    894,732
# 49   Harvey Keitel,Tim Roth,Michael Madsen,Chris Penn    885,154
#
#    Gross_In_Million
# 0            $28.34
# 1           $534.86
# 2           $292.58
# 3            $37.03
# 4           $107.93
# 5           $330.25
# 6           $171.48
# 7           $315.54
# 8           $377.85
# 9           $134.97
# 10          $448.14
# 11          $342.55
# 12          $100.13
# 13          $162.81
# 14          $187.71
# 15          $206.85
# 16          $623.28
# 17          $130.74
# 18          $120.54
# 19          $322.74
# 20          $216.54
# 21           $96.90
# 22          $132.38
# 23           $53.09
# 24          $290.48
# 25          $136.80
# 26          $760.51
# 27           $25.54
# 28           $57.30
# 29          $128.01
# 30          $130.10
# 31          $659.33
# 32          $210.61
# 33            $6.72
# 34           $70.51
# 35          $305.41
# 36           $19.50
# 37           $46.84
# 38           $70.10
# 39          $204.84
# 40          $223.81
# 41           $23.34
# 42           $75.60
# 43          $309.13
# 44          $380.84
# 45          $318.41
# 46          $422.78
# 47          $293.00
# 48          $125.62
# 49            $2.83

# %% [markdown]
# ### Now Save the DataFrame as a CSV file to use it later on Data Visualization
# #### we have out csv file to perform the analysis. so, we can able to use it visualize and understand the data and their relations
# ##### Now we can able to use this data to create NLP Model or Machine learning for predictions

# %%
IMDB_Movie_Data.to_csv("IMDB_MOVIES.csv")
